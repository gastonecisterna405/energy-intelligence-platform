# %% [markdown]
# # 02 Demand Forecasting
# Review actual vs predicted demand and forecasting metrics.

# %%
import json, pandas as pd
forecasts = pd.read_csv('../data/processed/demand_forecasts.csv')
metrics = json.load(open('../outputs/metrics/demand_model_metrics.json'))
display(forecasts.head())
metrics
