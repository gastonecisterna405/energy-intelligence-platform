# %% [markdown]
# # 05 NLP Energy Text Analysis
# Review extracted terms and comment categories.

# %%
import pandas as pd
terms = pd.read_csv('../outputs/metrics/nlp_top_terms.csv')
comments = pd.read_csv('../data/processed/nlp_comments.csv')
display(terms.head(20))
display(comments)
