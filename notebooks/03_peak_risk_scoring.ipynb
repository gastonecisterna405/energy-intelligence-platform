# %% [markdown]
# # 03 Peak Risk Scoring
# Inspect risk labels, scores and classification metrics.

# %%
import json, pandas as pd
risk = pd.read_csv('../data/processed/peak_risk_scores.csv')
metrics = json.load(open('../outputs/metrics/peak_risk_metrics.json'))
display(risk.sort_values('risk_score', ascending=False).head())
metrics
