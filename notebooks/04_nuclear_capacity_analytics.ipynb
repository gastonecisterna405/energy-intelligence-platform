# %% [markdown]
# # 04 Nuclear Capacity Analytics
# Analyze nuclear capacity by country, region and status.

# %%
import pandas as pd
country = pd.read_csv('../data/processed/nuclear_by_country.csv')
region = pd.read_csv('../data/processed/nuclear_by_region.csv')
display(country.head(10))
display(region)
